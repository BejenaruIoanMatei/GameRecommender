# %% [markdown]
# # About this notebook
#
# -   ### Enhanced Text Preprocessing
#
#     -   Unlike the main notebook, this version uses a deep-cleaning pipeline for the About the game column, removing HTML noise, special characters, and boilerplate Steam text to ensure the TF-IDF model focuses on actual gameplay descriptions.
#
# -  ### Feature Engineering (Metadata Soup):
#
#     -   **Unified Metadata**: Created a metadata_features column by merging Genres and Tags into unique, space-separated tokens.
#
#     -   **Categorical Weighting:** Integrated Developers, Publishers, and Categories into the text soup to allow the model to recognize brand and functional similarities (e.g., "co-op" or "roguelike").
#
# -  ### Hybrid Similarity Logic:
#
#     -   TF-IDF + Cosine Similarity: Captures the semantic "vibe" and narrative of the games.
#
#     -   Jaccard Similarity: Specifically used for Tags to ensure that games with identical community-driven labels are prioritized.
#
#     -   Alpha Blending: A weighted scoring system that balances description-based similarity with tag-based similarity.

# %% [markdown]
# ### Importing the dataset

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_to_dataset = 'dataset/games.csv'

if not os.path.isfile(path_to_dataset):
    print("not ok")

# %%
df = pd.read_csv(path_to_dataset)
df.head(n=3)
# Out:
#      AppID              Name  Release date Estimated owners  Peak CCU  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    Required age  Price  DiscountDLC count  About the game  \
# 0             0  19.99                  0               0
# 1             0   0.99                  0               0
# 2             0   4.99                  0               0
#
#                                  Supported languages  ...  \
# 0  Galactic Bowling is an exaggerated and stylize...  ...
# 1  THE LAW!! Looks to be a showdown atop a train....  ...
# 2  Jolt Project: The army now has a new robotics ...  ...
#
#   Median playtime forever Median playtime two weeks Developers  \
# 0                       0                         0          0
# 1                       0                         0          0
# 2                       0                         0          0
#
#               Publishers             Categories  \
# 0  Perpetual FX Creative  Perpetual FX Creative
# 1           Rusty Moyher           Wild Rooster
# 2          Campião Games          Campião Games
#
#                                               Genres  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                               Tags  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                          Screenshots  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                               Movies  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Others
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [3 rows x 40 columns]

# %% [markdown]
# ### Exploring the dataset

# %%
df.shape
# Out:
# (111452, 40)

# %%
df.describe()
# Out:
#               AppID      Peak CCU   Required age          Price  \
# count  1.114520e+05  1.114520e+05  111452.000000  111452.000000
# mean   1.716972e+06  1.777215e+02       0.254208       7.061568
# std    9.203859e+05  8.390462e+03       2.035653      12.563246
# min    1.000000e+01  0.000000e+00       0.000000       0.000000
# 25%    9.362550e+05  0.000000e+00       0.000000       0.990000
# 50%    1.665065e+06  0.000000e+00       0.000000       3.990000
# 75%    2.453585e+06  1.000000e+00       0.000000       9.990000
# max    3.671840e+06  1.311366e+06      21.000000     999.980000
#
#        DiscountDLC count  About the game  Metacritic url       Positive  \
# count      111452.000000   111452.000000   111452.000000  111452.000000
# mean            0.464209        0.449530        2.623354       0.030408
# std             3.503658       12.006677       13.736245       1.565136
# min             0.000000        0.000000        0.000000       0.000000
# 25%             0.000000        0.000000        0.000000       0.000000
# 50%             0.000000        0.000000        0.000000       0.000000
# 75%             0.000000        0.000000        0.000000       0.000000
# max            92.000000     2366.000000       97.000000     100.000000
#
#            Negative     Score rank  Achievements  Recommendations  \
# count  1.114520e+05  111452.000000     44.000000    111452.000000
# mean   7.543525e+02     125.859177     98.909091        17.511144
# std    2.139410e+04    4002.844431      0.857747       150.139008
# min    0.000000e+00       0.000000     97.000000         0.000000
# 25%    0.000000e+00       0.000000     98.000000         0.000000
# 50%    3.000000e+00       1.000000     99.000000         0.000000
# 75%    2.900000e+01       8.000000    100.000000        17.000000
# max    5.764420e+06  895978.000000    100.000000      9821.000000
#
#               Notes  Average playtime two weeks  Median playtime forever  \
# count  1.114520e+05               111452.000000            111452.000000
# mean   6.163715e+02                   81.247290                 9.174954
# std    1.573854e+04                  999.935906               168.201030
# min    0.000000e+00                    0.000000                 0.000000
# 25%    0.000000e+00                    0.000000                 0.000000
# 50%    0.000000e+00                    0.000000                 0.000000
# 75%    0.000000e+00                    0.000000                 0.000000
# max    3.441592e+06               145727.000000             19159.000000
#
#        Median playtime two weeks     Developers
# count              111452.000000  111452.000000
# mean                   72.651330       9.891038
# std                  1321.333137     183.232812
# min                     0.000000       0.000000
# 25%                     0.000000       0.000000
# 50%                     0.000000       0.000000
# 75%                     0.000000       0.000000
# max                208473.000000   19159.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111452 entries, 0 to 111451
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       111452 non-null  int64
#  1   Name                        111446 non-null  object
#  2   Release date                111452 non-null  object
#  3   Estimated owners            111452 non-null  object
#  4   Peak CCU                    111452 non-null  int64
#  5   Required age                111452 non-null  int64
#  6   Price                       111452 non-null  float64
#  7   DiscountDLC count           111452 non-null  int64
#  8   About the game              111452 non-null  int64
#  9   Supported languages         104969 non-null  object
#  10  Full audio languages        111452 non-null  object
#  11  Reviews                     111452 non-null  object
#  12  Header image                10624 non-null   object
#  13  Website                     111452 non-null  object
#  14  Support url                 46458 non-null   object
#  15  Support email               50759 non-null   object
#  16  Windows                     92427 non-null   object
#  17  Mac                         111452 non-null  bool
#  18  Linux                       111452 non-null  bool
#  19  Metacritic score            111452 non-null  bool
#  20  Metacritic url              111452 non-null  int64
#  21  User score                  4005 non-null    object
#  22  Positive                    111452 non-null  int64
#  23  Negative                    111452 non-null  int64
#  24  Score rank                  111452 non-null  int64
#  25  Achievements                44 non-null      float64
#  26  Recommendations             111452 non-null  int64
#  27  Notes                       111452 non-null  int64
#  28  Average playtime forever    18449 non-null   object
#  29  Average playtime two weeks  111452 non-null  int64
#  30  Median playtime forever     111452 non-null  int64
#  31  Median playtime two weeks   111452 non-null  int64
#  32  Developers                  111452 non-null  int64
#  33  Publishers                  104977 non-null  object
#  34  Categories                  104674 non-null  object
#  35  Genres                      103886 non-null  object
#  36  Tags                        105012 non-null  object
#  37  Screenshots                 74029 non-null   object
#  38  Movies                      107260 non-null  object
#  39  Others                      101832 non-null  object
# dtypes: bool(3), float64(2), int64(15), object(20)
# memory usage: 31.8+ MB

# %%
df.head(n=3)
# Out:
#      AppID              Name  Release date Estimated owners  Peak CCU  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    Required age  Price  DiscountDLC count  About the game  \
# 0             0  19.99                  0               0
# 1             0   0.99                  0               0
# 2             0   4.99                  0               0
#
#                                  Supported languages  ...  \
# 0  Galactic Bowling is an exaggerated and stylize...  ...
# 1  THE LAW!! Looks to be a showdown atop a train....  ...
# 2  Jolt Project: The army now has a new robotics ...  ...
#
#   Median playtime forever Median playtime two weeks Developers  \
# 0                       0                         0          0
# 1                       0                         0          0
# 2                       0                         0          0
#
#               Publishers             Categories  \
# 0  Perpetual FX Creative  Perpetual FX Creative
# 1           Rusty Moyher           Wild Rooster
# 2          Campião Games          Campião Games
#
#                                               Genres  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                               Tags  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                          Screenshots  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                               Movies  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Others
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [3 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies',
#        'Others'],
#       dtype='object')

# %%
idx = df.columns.get_loc('About the game')
idx
# Out:
# 8

# %%
df.iloc[:, idx:-1] = df.iloc[:, idx+1:].values

df = df.iloc[:, :-1]
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# /var/folders/7j/_p9t5tjd6cv81x2zrk834f_40000gn/T/ipykernel_15100/1070676544.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['Perpetual FX Creative', 'Rusty Moyher', 'Campião Games', 'Odd Critter Games', 'Unusual Games', '7Road', 'MAKSIM VOLKAU', 'magnussoft', 'Growing Seeds', 'ONE MORE LEVEL', 'Pixelated Milk', 'Wise Wizard Games, LLC', 'Beardlings LLC', 'Educational Games', 'Parange Project', 'Team17 Digital Ltd', 'SCS Software', 'Lonely Troops', 'KENZsoft', 'Necavare', 'Bretwalda Games', 'Volens Nolens Games', 'IPACS', 'Falco Software', 'SGデベロッパー', 'PseudoGames', 'Zero One', 'Mens Sana Interactive', 'Delta Arcade', 'GameUncle', 'NedoStudio', 'lonch.me', 'TensionSplice', 'Warped Tales', 'Dark Water Studios Ltd', 'FAYEZ ALRASHEEDI,WADE AIZOUKY,KHALED ALRASHEEDI', 'Team Spikkeee', 'Century Game', 'Lame Jam', 'Tomoaki Sugeno', 'Black Beach Studio', 'Garage Games,Jan Hess', 'The Farm 51', 'Chroma Field Games', 'Nerial', 'GoldFire Studios', '玫瑰工作室', 'Ubisoft Montreal,Red Storm,Ubisoft Shanghai,Ubisoft Toronto,Ubisoft Kiev', 'Boogygames Studios', 'Arc System Works', 'Elephant Games', 'Stegalosaurus Game Development', 'Uintani', 'Righteous Weasel Games,Ignatios Prouctions LLC', 'Team Sämst', 'Hello Friend LLC', 'RunServer', 'Playground Games', 'VikingWarrior', '折凳工作室', 'KanakStudio', 'Julian Henley', 'Gremlin Interactive,The Software Refinery', 'Peaksel', 'aNCHOR Inc.,fuzz, Inc.', 'SparkGames', 'Remedy Entertainment', 'PICTOLOGI', 'Berry Berry Niceu', 'Avalon Digital,Cyril Jarnot', 'Ballistic Machine', 'Portable Moose', 'Soiree Games', 'Woodsy Studio', 'Miniced', 'Madman Games,RattlerCreed', 'Retrover Games', 'FireArmGames', 'Tero Lunkka,BlackThug', 'Debonosu Works', 'Team Good Knight', 'Cateia Games', 'Flying Panjandrum / ふらいんぐパンジャンドラム', 'Aligned Games', 'PixQuake', 'Nucleax', 'Boogygames Studios', 'Seacoxx', 'Tudor Sandru', "Kiro'o Games", 'Undercoders', 'Slippy Floor', 'Teleporter Realities Inc.', 'Reiza Studios', 'Marching Simulator', 'SimulaM', 'Klei Entertainment', 'LGT SIA', 'Pinblend Studios', 'Gemdrops, Inc.', 'Goadstool', 'NukGames', 'Davioware and Quazi', 'Quantized Bit', 'Brainwashing games', nan, 'Pablo Picazo', 'Heavy Iron Studios', 'SOFTON ENTERTAINMENT', 'Pretty Bat Games', 'NewProjekt', 'Marcin Mikołajczyk', 'Sonic Team,Bitbaboon', 'Cobra Mobile', 'seagull home', 'Reforged Group', 'KOEI TECMO GAMES CO., LTD.', 'Abstraction Games,The Bitmap Brothers', 'Purple Cable', 'WanadevStudio', 'Mozg Labs', 'Four Circle Interactive', '豆干叠叠木', 'MOGA Creative', 'Joe Chisholm', 'Artur Rezende', 'Stegalosaurus Game Development', 'Straight Back Games', 'Canuck Play Inc', 'Yima VLG.', 'GoesSoft', 'Triority Interactive Novels', 'Unfinished Pixel', 'Royal Flush Studioz', 'Gamera Interactive', 'Aleksi Rajamäki,Matias Rajamäki', 'Infinity Ward', 'ElZzap Software', 'PomPom Games', 'Ezhaac Studio', 'RecordRecordsGame', 'Creobit', 'Interplay', 'My Oldschool Console', 'Big Village Games Ltd', 'VRANI inc.', 'POWER UNIT,APOLLOSOFT', 'Sayan', '祥', 'Andorf Games', 'Toolkitz Games', 'Academtech LLC', 'Bisquit Play', 'thatgamecompany', 'R.E.M. Studios,NullReferenceException', 'meokigame', 'Pixel Racers', 'Riftpoint Entertainment', 'BigGame Studio', 'Bloodwolf Studio', 'Delve Interactive', '有杕之杜', 'LUXO Interactive', 'Lionsart', 'Furyface', 'Last Day Of Work', '0', 'HugePixel, Diedemor studio', 'Unikgame', 'GuGong', 'Kevin Nguyen', 'Mifos Games', 'Dribble Games', 'Eponymouse', 'Team Jolly Roger', 'Cracked Heads Games', 'Vivid Helix', 'Three Prong Productions', 'Rionix', 'Joe Chatfield', nan, 'S. Khasanov', 'Lange Studios LLC', 'Stanislaw Truchowski', 'Metthink', 'Indie Light', 'Tomas Daugela', 'Nihon Falcom', 'KOEI TECMO GAMES CO., LTD.', 'INFINITE BRIDGE', 'Suomi-Peli', 'Retrific', 'Igor Neiman', 'Strong Cube', 'Leturs Labs', 'Dodo Digital', 'Bandai Namco Studios Inc.', 'NikiGames', 'XDEVS LTD', 'Space Driver', 'Cheesemaster Games', 'Split Light Studio', 'Adaptive Game',  ...
#   df.iloc[:, idx:-1] = df.iloc[:, idx+1:].values

# %%
df.head(n=3)
# Out:
#      AppID              Name  Release date Estimated owners  Peak CCU  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    Required age  Price  DiscountDLC count  \
# 0             0  19.99                  0
# 1             0   0.99                  0
# 2             0   4.99                  0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
#
#                                  Supported languages  ...  \
# 0                                        ['English']  ...
# 1  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2                 ['English', 'Portuguese - Brazil']  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
# 1                          0                       0
# 2                          0                       0
#
#   Median playtime two weeks             Developers             Publishers  \
# 0                         0  Perpetual FX Creative  Perpetual FX Creative
# 1                         0           Rusty Moyher           Wild Rooster
# 2                         0          Campião Games          Campião Games
#
#                                           Categories  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                             Genres  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                                 Tags  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [3 rows x 39 columns]

# %%
df.to_csv("test.csv")

# %%
df.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies'],
#       dtype='object')

# %%
df['Developers'].value_counts()
# Out:
# Developers
# EroticGamesClub             216
# Choice of Games             166
# Laush Dmitriy Sergeevich    149
# Boogygames Studios          145
# Creobit                     138
#                            ...
# Studio Binokle                1
# GIBBING TREE, LLC             1
# BitCore Studios LLC           1
# SOMOV KIRILL                  1
# Ledx                          1
# Name: count, Length: 64655, dtype: int64

# %%
def clean_data(x):
    if isinstance(x, str):
        return x.replace(" ", "").lower()
    else:
        return ''

df['Developers_clean'] = df['Developers'].apply(clean_data)
df['Publishers_clean'] = df['Publishers'].apply(clean_data)

# %%
df.head(n=3)
# Out:
#      AppID              Name  Release date Estimated owners  Peak CCU  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    Required age  Price  DiscountDLC count  \
# 0             0  19.99                  0
# 1             0   0.99                  0
# 2             0   4.99                  0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
#
#                                  Supported languages  ...  \
# 0                                        ['English']  ...
# 1  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2                 ['English', 'Portuguese - Brazil']  ...
#
#   Median playtime two weeks             Developers             Publishers  \
# 0                         0  Perpetual FX Creative  Perpetual FX Creative
# 1                         0           Rusty Moyher           Wild Rooster
# 2                         0          Campião Games          Campião Games
#
#                                           Categories  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                             Genres  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                                 Tags  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies     Developers_clean  \
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...  perpetualfxcreative
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...          rustymoyher
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...         campiãogames
#
#       Publishers_clean
# 0  perpetualfxcreative
# 1          wildrooster
# 2         campiãogames
#
# [3 rows x 41 columns]

# %%
def merge_and_clean_tags(row):
    genres = str(row['Genres']).lower().split(',')
    tags = str(row['Tags']).lower().split(',')

    genres = [g.strip().replace(' ', '') for g in genres]
    tags = [t.strip().replace(' ', '') for t in tags]

    combined = list(set(genres + tags))

    return ' '.join(combined)

df['metadata_features'] = df.apply(merge_and_clean_tags, axis=1)

# %%
df.head(n=3)
# Out:
#      AppID              Name  Release date Estimated owners  Peak CCU  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    Required age  Price  DiscountDLC count  \
# 0             0  19.99                  0
# 1             0   0.99                  0
# 2             0   4.99                  0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
#
#                                  Supported languages  ...  \
# 0                                        ['English']  ...
# 1  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2                 ['English', 'Portuguese - Brazil']  ...
#
#               Developers             Publishers  \
# 0  Perpetual FX Creative  Perpetual FX Creative
# 1           Rusty Moyher           Wild Rooster
# 2          Campião Games          Campião Games
#
#                                           Categories  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                             Genres  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                                 Tags  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies     Developers_clean  \
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...  perpetualfxcreative
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...          rustymoyher
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...         campiãogames
#
#       Publishers_clean                                  metadata_features
# 0  perpetualfxcreative                        bowling sports indie casual
# 1          wildrooster  arcade difficult singleplayer blood casual act...
# 2         campiãogames                nan strategy action adventure indie
#
# [3 rows x 42 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies',
#        'Developers_clean', 'Publishers_clean', 'metadata_features'],
#       dtype='object')

# %%
df['About the game'][6]
# Out:
# 'TD Worlds is a dynamic, highly strategical game that challenges your skill. Build an impenetrable defense and get ready to plunge into a new, unknown world to uncover its secrets. In this bizarre universe, each attempt will be unique in its own way, which provides many hours of fun to play. Clear three completely different worlds from darkness, spread your influence everywhere. unique conditions in each game; losing is an important part of game progress. Each defeat reveals something new for you; dynamic storytelling: the more you play, the more you learn about the world; get random rewards after each level; tired of playing? Feel free to leave the game, next time you will continue where you left; experiment with different tactics; Twitch integration - play with your viewers.'

# %%
import re
from bs4 import BeautifulSoup

# %%
def clean_description(text):
    if not isinstance(text, str):
        return ""

    text = BeautifulSoup(text, "html.parser").get_text(separator=" ")

    text = re.sub(r'[™®©]', '', text)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)

    text = text.lower().strip()
    text = " ".join(text.split())

    return text

df['About the game_clean'] = df['About the game'].apply(clean_description)
# Out:
# /var/folders/7j/_p9t5tjd6cv81x2zrk834f_40000gn/T/ipykernel_15100/3037115924.py:5: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "html.parser").get_text(separator=" ")

# %%
df.to_csv('test.csv')

# %%
df.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies',
#        'Developers_clean', 'Publishers_clean', 'metadata_features',
#        'About the game_clean'],
#       dtype='object')

# %%
df['Categories'][1]
# Out:
# 'Single-player,Steam Achievements,Full controller support,Steam Leaderboards,Remote Play on Phone,Remote Play on Tablet,Remote Play on TV'

# %%
def clean_categories(text):
    if not isinstance(text, str):
        return ""

    parts = text.split(',')
    clean_parts = [p.strip().replace(' ', '').replace('-', '').lower() for p in parts]
    return " ".join(clean_parts)

df['Categories_clean'] = df['Categories'].apply(clean_categories)

# %%
df['Categories_clean'][1]
# Out:
# 'singleplayer steamachievements fullcontrollersupport steamleaderboards remoteplayonphone remoteplayontablet remoteplayontv'

# %%
cols_to_keep = ['AppID', 'Name', 'Positive', 'Negative', 'About the game_clean', 'metadata_features', 'Categories_clean', 'Developers_clean', 'Publishers_clean']

df = df[cols_to_keep]

# %%
df.head(n=3)
# Out:
#      AppID              Name  Positive  Negative  \
# 0    20200  Galactic Bowling         6        11
# 1   655370      Train Bandit        53         5
# 2  1732930      Jolt Project         0         0
#
#                                 About the game_clean  \
# 0  galactic bowling is an exaggerated and stylize...
# 1  the law looks to be a showdown atop a train th...
# 2  jolt project the army now has a new robotics p...
#
#                                    metadata_features  \
# 0                        bowling sports indie casual
# 1  arcade difficult singleplayer blood casual act...
# 2                nan strategy action adventure indie
#
#                                     Categories_clean     Developers_clean  \
# 0  singleplayer multiplayer steamachievements par...  perpetualfxcreative
# 1  singleplayer steamachievements fullcontrollers...          rustymoyher
# 2                                       singleplayer         campiãogames
#
#       Publishers_clean
# 0  perpetualfxcreative
# 1          wildrooster
# 2         campiãogames

# %%
df.to_csv('selected_data.csv')

# %%
df['About the game_clean'].isna().sum()
# Out:
# 0

# %%
df['Name'].isna().sum()
# Out:
# 6

# %%
df = df.dropna(subset=['Name', 'About the game_clean'])

# %%
df[df['About the game_clean'].str.strip() == ""]
# Out:
#           AppID                                   Name  Positive  Negative  \
# 105     1943590                         溪风谷之战 Playtest         0         0
# 180     1966960                  Burial Stone Playtest         0         0
# 214     1688630              Emperial Knights Playtest         0         0
# 220     1478660                 Slotracers VR Playtest         0         0
# 291     1613340  Pirates of the Asteroid Belt Playtest         0         0
# ...         ...                                    ...       ...       ...
# 111401  2078010                 Legends of Immortality        47        29
# 111405  3670540               Boiiing Boiiing Playtest         0         0
# 111417  3609290                           月之冕 Playtest         0         0
# 111434  3654520                    Delusional Playtest         0         0
# 111439  3012940                 Forgery Craft Playtest         0         0
#
#        About the game_clean  \
# 105
# 180
# 214
# 220
# 291
# ...                     ...
# 111401
# 111405
# 111417
# 111434
# 111439
#
#                                         metadata_features  \
# 105                                                   nan
# 180                                                   nan
# 214                                                   nan
# 220                                                   nan
# 291                                                   nan
# ...                                                   ...
# 111401  combat tacticalrpg rpg 2d strategy earlyaccess...
# 111405                                                nan
# 111417                                                nan
# 111434                                                nan
# 111439                                                nan
#
#                                     Categories_clean Developers_clean  \
# 105
# 180
# 214
# 220
# 291
# ...                                              ...              ...
# 111401  singleplayer steamachievements familysharing           云梦山工作室
# 111405
# 111417
# 111434
# 111439
#
#        Publishers_clean
# 105
# 180
# 214
# 220
# 291
# ...                 ...
# 111401   方块游戏(cubegame)
# 111405
# 111417
# 111434
# 111439
#
# [6709 rows x 9 columns]

# %%
df = df[df['About the game_clean'].str.strip() != ""]

# %%
df.shape
# Out:
# (104737, 9)

# %%
cols_to_fix = ['metadata_features', 'Categories_clean', 'Developers_clean', 'Publishers_clean']
df[cols_to_fix] = df[cols_to_fix].fillna('')

# %%
df.isna().sum()
# Out:
# AppID                   0
# Name                    0
# Positive                0
# Negative                0
# About the game_clean    0
# metadata_features       0
# Categories_clean        0
# Developers_clean        0
# Publishers_clean        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['AppID', 'Name', 'Positive', 'Negative', 'About the game_clean',
#        'metadata_features', 'Categories_clean', 'Developers_clean',
#        'Publishers_clean'],
#       dtype='object')

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['combined'] = (
    df['About the game_clean'] + ' ' +
    df['metadata_features'] + ' ' +
    df['Categories_clean'] + ' '
    # df['Developers_clean'] + ' ' +
    # df['Publishers_clean']
)

df['combined'] = df['combined'].apply(lambda x: " ".join(x.split()))

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english')
games_vector = vectorizer.fit_transform(df['combined'])

# %%
type(vectorizer)
# Out:
# sklearn.feature_extraction.text.TfidfVectorizer

# %% [markdown]
# ### Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def process_tags_to_set(tags_str):
    if not isinstance(tags_str, str):
        return set()
    return set([t.strip().lower() for t in tags_str.split(',')])

df['tags_set'] = df['metadata_features'].apply(process_tags_to_set)

# %%
def jaccard_similarity(set1, set2):
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union != 0 else 0

# %%
def recommend_game(title, n_recommendation=5, alpha=0.3):
    """
    alpha = 0.3: 30% conteaza Cosine Similarity (Text), 70% conteaza Jaccard (Tags).
    """
    title = title.lower().strip()

    if 'name_norm' not in df.columns:
        df['name_norm'] = df['Name'].str.lower().str.strip()

    if title not in df['name_norm'].values:
        return {"error": "Game not found. Please check the name and try again."}

    g_idx = df[df['name_norm'] == title].index[0]

    current_game_tags = df.loc[g_idx, 'tags_set']
    jaccard_scores = [
        0 if idx == g_idx else jaccard_similarity(
            current_game_tags, df.loc[idx, 'tags_set']
        )
        for idx in range(len(df))
    ]

    jaccard_scores = np.array(jaccard_scores)
    if np.max(jaccard_scores) > 0:
        jaccard_scores /= np.max(jaccard_scores)

    cosine_scores = cosine_similarity(games_vector[g_idx], games_vector).flatten()

    if np.max(cosine_scores) > 0:
        cosine_scores /= np.max(cosine_scores)

    final_score = alpha * cosine_scores + (1 - alpha) * jaccard_scores
    recomm_idx = final_score.argsort()[::-1][1:n_recommendation + 1]

    recommendations = []
    for idx in recomm_idx:
        game_name = df.iloc[idx]['Name']
        game_image = df.iloc[idx].get('Header image', '')
        score = round(final_score[idx], 3)

        recommendations.append({
            "name": game_name,
            "image": game_image,
            "score": score
        })

    return {
        "input": title,
        "recommendations": recommendations
    }

# %%
title = 'phasmophobia'
print(recommend_game(title))
# Out:
# {'input': 'phasmophobia', 'recommendations': [{'name': 'Evil Hunt - Evil never sleeps', 'image': '', 'score': 0.177}, {'name': 'Paranormal Home Invaders', 'image': '', 'score': 0.129}, {'name': 'Ghostbane', 'image': '', 'score': 0.123}, {'name': 'BE HUNTED', 'image': '', 'score': 0.12}, {'name': 'Friki', 'image': '', 'score': 0.12}]}

# %%
title = 'The Crew™ 2'
print(recommend_game(title))
# Out:
# {'input': 'the crew™ 2', 'recommendations': [{'name': 'Automobilista 2', 'image': '', 'score': 0.063}, {'name': 'The Crew™', 'image': '', 'score': 0.05}, {'name': 'Project CARS', 'image': '', 'score': 0.049}, {'name': 'Space Haven', 'image': '', 'score': 0.046}, {'name': 'TNN Motorsports Hardcore TR', 'image': '', 'score': 0.043}]}
